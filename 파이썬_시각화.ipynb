# %% [markdown]
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/17-Pandas_Plot_Series_DataFrame.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl #파이썬 내의 데이터 활용
import matplotlib.pyplot as plt
# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제 대처

# %% [markdown]
# # plot으로 그릴 수 있는 그래프

# %% [markdown]
# ## kind : str
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %% [markdown]
# # 누적합 + plot

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01   -0.280614
# 2000-01-02   -1.270029
# 2000-01-03    0.239438
# 2000-01-04    0.265464
# 2000-01-05    0.757452
#                 ...
# 2002-09-22   -0.201581
# 2002-09-23    0.244862
# 2002-09-24   -0.519053
# 2002-09-25   -2.552829
# 2002-09-26    2.099964
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts = ts.cumsum() #누적합

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.251799  0.225456 -0.508186 -0.854211
# 2000-01-02  0.924320 -0.223993 -0.458741 -0.413660
# 2000-01-03 -1.074799  0.650941 -0.753312 -0.070827
# 2000-01-04  0.601119  1.288358  1.021883 -1.098717
# 2000-01-05  0.552859  0.492249 -0.450479 -1.666756
# ...              ...       ...       ...       ...
# 2002-09-22  0.395384  0.008432 -0.348280 -0.737115
# 2002-09-23 -0.183974  0.560400 -2.100928 -0.220225
# 2002-09-24 -0.796194 -0.347611  0.359471 -0.558883
# 2002-09-25 -0.724102  0.988929  2.093281  1.351881
# 2002-09-26  0.182724 -0.226623  0.706465  0.089449
#
# [1000 rows x 4 columns]

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.plot()

# %%
df = df.cumsum() #누적합
df
# Out:
#                     A          B         C          D
# 2000-01-01   0.251799   0.225456 -0.508186  -0.854211
# 2000-01-02   1.176119   0.001462 -0.966927  -1.267870
# 2000-01-03   0.101320   0.652403 -1.720239  -1.338698
# 2000-01-04   0.702439   1.940762 -0.698356  -2.437414
# 2000-01-05   1.255299   2.433010 -1.148835  -4.104171
# ...               ...        ...       ...        ...
# 2002-09-22 -22.162139  24.480584  1.333780 -18.814271
# 2002-09-23 -22.346113  25.040984 -0.767148 -19.034496
# 2002-09-24 -23.142307  24.693373 -0.407677 -19.593380
# 2002-09-25 -23.866410  25.682302  1.685605 -18.241499
# 2002-09-26 -23.683686  25.455680  2.392069 -18.152049
#
# [1000 rows x 4 columns]

# %%
df.plot() #누적합 그래프

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3
# Out:
#              B          C
# 0     0.623136   0.413068
# 1     1.126888   1.552961
# 2    -0.275618   0.946532
# 3     0.905626   0.056551
# 4     0.598858  -0.057220
# ..         ...        ...
# 995  44.813565  17.262950
# 996  46.048049  17.999333
# 997  44.577071  15.740305
# 998  44.821313  16.596684
# 999  44.169383  16.196270
#
# [1000 rows x 2 columns]

# %%
df3.head() #인덱스 0부터
# Out:
#           B         C
# 0  0.623136  0.413068
# 1  1.126888  1.552961
# 2 -0.275618  0.946532
# 3  0.905626  0.056551
# 4  0.598858 -0.057220

# %%
len(df)
range(len(df))
#list(range(len(df)))
# Out:
# range(0, 1000)

# %%
df3['A']=pd.Series(list(range(len(df)))) #A라는 컬럼 추가

# %%
df3
# Out:
#              B          C    A
# 0     0.623136   0.413068    0
# 1     1.126888   1.552961    1
# 2    -0.275618   0.946532    2
# 3     0.905626   0.056551    3
# 4     0.598858  -0.057220    4
# ..         ...        ...  ...
# 995  44.813565  17.262950  995
# 996  46.048049  17.999333  996
# 997  44.577071  15.740305  997
# 998  44.821313  16.596684  998
# 999  44.169383  16.196270  999
#
# [1000 rows x 3 columns]

# %%
df3.plot(x='A', y='B')

# %%
df3.plot(y='B')

# %% [markdown]
# # Bar plot
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/18-Pandas_bar_plot.ipynb

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000)) #2000.1.1부터 1000일간 
ts.head()
# Out:
# 2000-01-01    1.347287
# 2000-01-02    0.847678
# 2000-01-03    0.997290
# 2000-01-04    1.433109
# 2000-01-05    0.579898
# Freq: D, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))
df.head(6)
# Out:
#                    A         B         C         D
# 2000-01-01  1.110377  1.380558 -1.485294  1.658325
# 2000-01-02  0.598038  1.005750 -0.380946 -0.375797
# 2000-01-03  0.096884 -1.258184 -0.359383 -1.523816
# 2000-01-04  0.600642 -1.290921 -0.669104  0.405728
# 2000-01-05 -1.536271 -0.190326  0.345530  0.227553
# 2000-01-06  0.938982  1.225743 -1.018601 -0.311180

# %%
df.tail(6)
# Out:
#                    A         B         C         D
# 2002-09-21  0.478124  0.152399  0.505048  0.930497
# 2002-09-22 -0.989975 -0.701625  1.064617  0.933850
# 2002-09-23 -1.042834  0.048343 -1.835083 -0.740076
# 2002-09-24  0.481581 -0.261378 -1.888281 -1.772641
# 2002-09-25  0.441678 -0.851308  0.211787  0.069015
# 2002-09-26  1.840728  0.133880  0.935996 -0.634723

# %%
df.iloc[5] #인덱스가 5인 행의 값 가져오기
# Out:
# A    0.938982
# B    1.225743
# C   -1.018601
# D   -0.311180
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind='bar')

# %%
df.iloc[5].plot.bar()

# %% [markdown]
# plot.(Tab키)를 누르면 plot의 종류 나옴

# %%
#plt사용(중간 선)
df.iloc[5].plot.bar() 
plt.axhline(0, color='k') #가로선

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd']) #10개의 행과 4개의 열
df2.head(3)
# Out:
#           a         b         c         d
# 0  0.061652  0.862254  0.141178  0.678927
# 1  0.222323  0.235612  0.495172  0.586746
# 2  0.745343  0.752179  0.547410  0.748610

# %%
df2.plot.bar()

# %% [markdown]
# ### 위로 쌓은 bar plot

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# ### 가로 bar plot

# %%
df2.plot.barh()

# %% [markdown]
# ### 옆으로 쌓은 bar plot

# %%
df2.plot.barh(stacked=True)

# %% [markdown]
# # 히스토그램-도수분포를 나타내는 한 방법
# 구간별 빈도수 표현\
# 가로와 세로를 함께 생각해야한다는 것!\
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/19-1-numpy_rand_randn_randint.ipynb

# %%
import matplotlib as mpl

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 
                    'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, 
                   columns=['a', 'b', 'c'])

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1,
                    'b':np.random.randn(1000),
                   'c':np.random.randn(1000)-1},
                  columns=['a','b','c']) #randn:표준정규분포에서 난수 생성

# %%
df4.head()
# Out:
#           a         b         c
# 0  1.088794  0.638544 -2.001941
# 1  0.248041  1.245886 -1.754842
# 2 -1.024210  0.560219 -0.498768
# 3  0.423847  1.330126 -0.758708
# 4 -0.879392 -0.749680 -1.149848

# %%
df4.plot.hist(alpha=0.5) #alpha는 투명도

# %% [markdown]
# bin(범위의 수)이 10개

# %%
df4.plot.hist(stacked=True, bins=20) #stacked는 누적

# %%
df4.plot.hist(bins=20)

# %% [markdown]
# ### 히스토그램 세로로 축 바꾸기
# orientation='horizontal'

# %%
df4['a'].plot.hist(orientation='horizontal', cumulative=True) #축 바꾸기, 누적

# %% [markdown]
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/19-20-Pandas_hist_plot.ipynb

# %% [markdown]
# # 차분해서 히스토그램 그리기
# 차분이란? Y(t)-Y(t-1)

# %%
df4['diff_a'] = df4['a'].diff()
df4[['a','diff_a']]
# Out:
#             a    diff_a
# 0    1.088794       NaN
# 1    0.248041 -0.840754
# 2   -1.024210 -1.272250
# 3    0.423847  1.448057
# 4   -0.879392 -1.303239
# ..        ...       ...
# 995 -1.276413 -5.164846
# 996  1.034165  2.310578
# 997 -0.235325 -1.269491
# 998 -0.174284  0.061041
# 999  0.091879  0.266163
#
# [1000 rows x 2 columns]

# %%
df4['shift_a'] = df4['a'].shift(1)

# %%
df4[['shift_a','a','diff_a']]
# Out:
#       shift_a         a    diff_a
# 0         NaN  1.088794       NaN
# 1    1.088794  0.248041 -0.840754
# 2    0.248041 -1.024210 -1.272250
# 3   -1.024210  0.423847  1.448057
# 4    0.423847 -0.879392 -1.303239
# ..        ...       ...       ...
# 995  3.888433 -1.276413 -5.164846
# 996 -1.276413  1.034165  2.310578
# 997  1.034165 -0.235325 -1.269491
# 998 -0.235325 -0.174284  0.061041
# 999 -0.174284  0.091879  0.266163
#
# [1000 rows x 3 columns]

# %%
df4['check_a'] = df4['a']-df4['shift_a']

# %%
df4[['check_a','diff_a']]
# Out:
#       check_a    diff_a
# 0         NaN       NaN
# 1   -0.840754 -0.840754
# 2   -1.272250 -1.272250
# 3    1.448057  1.448057
# 4   -1.303239 -1.303239
# ..        ...       ...
# 995 -5.164846 -5.164846
# 996  2.310578  2.310578
# 997 -1.269491 -1.269491
# 998  0.061041  0.061041
# 999  0.266163  0.266163
#
# [1000 rows x 2 columns]

# %%
df4[['a','b','c']].diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C82440C648>,
# ...
#       dtype=object)

# %%
data = pd.Series(np.random.randn(1000))
data= pd.DataFrame({'a': np.random.randn(1000),
                   'b':np.random.randint(0,4,1000)})
data.head()
# Out:
#           a  b
# 0  0.137072  2
# 1  0.220894  3
# 2 -0.514855  0
# 3 -2.149530  1
# 4  0.490864  0

# %% [markdown]
# ### 카테고리별 히스토그램 by는 카테고리 나눠주는 것

# %%
data.hist(by=np.random.randint(0,4,1000), figsize=(6,4)) #0~3까지 랜덤 숫자 만들고 그거별로 그룹나눔
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8244E66C8>,
# ...
#       dtype=object)

# %%
data.hist(by=data['b'], figsize=(6,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8248E0F48>,
# ...
#       dtype=object)

# %% [markdown]
# # box plot 그리기
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/21-Pandas_box_plot.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### rand 명령은 0과 1사이의 난수를 발생시키는 명령으로 인수로 받은 숫자 횟수만큼 난수를 발생

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E']) #10행 5열의 랜덤 숫자

# %%
df.describe() #요약된 수치
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.438491   0.601932   0.603977   0.458268   0.451899
# std     0.281485   0.349041   0.179262   0.335745   0.287380
# min     0.086844   0.086554   0.246868   0.026831   0.127413
# 25%     0.208635   0.257868   0.511515   0.212213   0.201449
# 50%     0.407942   0.749128   0.635143   0.409321   0.424433
# 75%     0.623810   0.853754   0.723301   0.744366   0.699088
# max     0.876036   0.977237   0.864271   0.927770   0.902491

# %%
df.plot.box()

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange',
        'medians': 'DarkBlue', 'caps': 'Gray'}             #색깔 바꾸기

# %%
df.plot.box(color=color, sym='r+')   #색바꾸기, 이상치 표시 바꾸기

# %%
df.plot.box(vert=False)   #x축 y축 바꾸기

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])   #position은 y축의 어느 위치에 둘건지..?

# %%
df = pd.DataFrame(np.random.rand(10,5))

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.587182  0.753799  0.866470  0.433511  0.058280
# 1  0.982148  0.339865  0.038215  0.661866  0.485919
# 2  0.970490  0.495089  0.508982  0.984484  0.493784
# 3  0.806084  0.980193  0.812492  0.560580  0.072508
# 4  0.121420  0.828378  0.252909  0.015135  0.629932
# 5  0.600153  0.792909  0.250490  0.627201  0.408847
# 6  0.602500  0.612640  0.556968  0.500219  0.077663
# 7  0.130270  0.100570  0.091433  0.876938  0.049918
# 8  0.320203  0.837137  0.767529  0.699961  0.037550
# 9  0.717914  0.901008  0.333224  0.295368  0.947613

# %% [markdown]
# ### 그리드 그려주기

# %%
plt.figure() #grid 그려주기

# %%
bp=df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Col1', 'Col2'])
df.head(2)
# Out:
#        Col1      Col2
# 0  0.766759  0.754613
# 1  0.490204  0.467137

# %%
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])
df.head(2)
# Out:
#        Col1      Col2  X
# 0  0.766759  0.754613  A
# 1  0.490204  0.467137  A

# %% [markdown]
# ### 카테고리별 boxplot

# %%
bp = df.boxplot(by='X')

# %%
df_box = pd.DataFrame(np.random.randn(50, 2))
df_box['g'] = np.random.choice(['A', 'B'], size=50)  
#choice는 이미 있는 데이터 집합에서 일부를 무작위로 선택하는 것을 샘플링(sampling), 여기선 ['A','B']중 랜덤으로 50개 고르기
df_box.head()
# Out:
#           0         1  g
# 0  2.607120 -0.382715  A
# 1 -1.280569  0.058477  B
# 2 -0.606416 -0.190122  A
# 3  0.454538  3.077523  B
# 4 -1.641597 -1.032015  B

# %%
df_box.loc[df_box['g'] == 'B', 1]
# Out:
# 1     0.058477
# 3     3.077523
# 4    -1.032015
# 8     2.712323
# 10   -1.156532
# 11   -0.353586
# 15   -0.314873
# 16    0.228809
# 19    1.267758
# 22    0.337716
# 24   -0.185768
# 26   -0.848808
# 27   -0.983211
# 28    0.331606
# 33   -0.309306
# 34    0.880874
# 35    0.219126
# 37    1.612270
# 38    1.006814
# 39    2.388502
# 43    0.759427
# 44    0.985976
# 45    1.471162
# Name: 1, dtype: float64

# %%
df_box.loc[df_box['g'] == 'B', 1] += 3 #df.loc[행 인덱싱값, 열 인덱싱값]
df_box.head()
# Out:
#           0         1  g
# 0  2.607120 -0.382715  A
# 1 -1.280569  3.058477  B
# 2 -0.606416 -0.190122  A
# 3  0.454538  6.077523  B
# 4 -1.641597  1.967985  B

# %%
bp = df_box.boxplot(by='g')
# Out:
# C:\python\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# C:\python\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
bp=df_box.groupby('g').boxplot() #bd처럼 다른 변수에 담아서 그리면 그리드도 그려줌!

# %%
df_box.groupby('g').boxplot()
# Out:
# A         AxesSubplot(0.1,0.15;0.363636x0.75)
# B    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %% [markdown]
# # Area plot, Grid 옵션으로 그래프 격자 만들기
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/22-Pandas_area_plot.ipynb

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.225671  0.938955  0.429062  0.131223
# 1  0.636333  0.717479  0.277893  0.505786
# 2  0.665880  0.514252  0.323127  0.791988
# 3  0.306384  0.627820  0.389104  0.032750
# 4  0.757390  0.566221  0.460347  0.824013

# %% [markdown]
# ### area plot - 누적하는게 기본(stacked=True)

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %%
df.plot.area(grid=True) #grid추가

# %% [markdown]
# # scatter plot(연관관계, 이상치 등 파악할 때)
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/23-Pandas_scatter_plot.ipynb

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.scatter(x='a',y='b', s=10) #s는 점의 크기

# %% [markdown]
# ### 데이터 두개 같은 그래프에 합치기

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkRed', label='Group 1') 
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax)

# %% [markdown]
# ### 축 세개

# %%
df.plot.scatter(x='a', y='b', c='c', s=100)

# %%
df.plot.scatter(x='a', y='b', s=df['c'] * 200) #c의 크기에 따라 도형 크기 달라짐

# %% [markdown]
# # Hexagonal Bin plot
# - 데이터가 클 때 각각의 점을 산점도로 표현할 때의 단점 보완\
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/24-Hexagonal_Bin_Plot.ipynb

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000) #0부터 999값을 순차적으로 더해줌

# %%
df.plot.hexbin(x='a', y='b', gridsize=10)

# %%
df.plot.scatter(x='a',y='b')

# %%
df['z'] = np.random.uniform(0, 3, 1000)

# %%
df.head()
# Out:
#           a         b         z
# 0  0.672802 -1.130213  2.514433
# 1 -1.039616  1.454926  0.224233
# 2  2.137287  1.326492  1.409408
# 3  0.021905  3.298828  1.653666
# 4  1.407700  0.909263  0.325894

# %%
df.plot.hexbin(x='a', y='b', C='z', gridsize=20)

# %%
df.plot.hexbin(x='a', y='b', C='z', 
               reduce_C_function=np.median, gridsize=20)

# %% [markdown]
# 기본적으로 각 (x, y) 점 주변의 개수에 대한 히스토그램이 계산됩니다. C 및 reduce_C_function 인수에 값을 전달하여 대체 집계를 지정할 수 있습니다. C는 각 (x, y) 점에서 값을 지정하고 reduce_C_function은 빈의 모든 값을 단일 숫자 (예 : 평균, 최대 값, 합계, 표준)로 줄이는 하나의 인수의 함수입니다. 이 예에서 위치는 열 (column) a 및 b에 의해 주어지며 값은 열 (z)에 의해 주어진다. 빈은 NumPy의 max 함수로 집계됩니다.\
# If given, these values are accumulated in the bins. Otherwise, every point has a value of 1. Must be of the same length as x and y.

# %%
df.plot.hexbin(x='a', y='b', C='z', 
               reduce_C_function=np.average, gridsize=20)

# %%
df.plot.hexbin(x='a', y='b', C='z', 
               reduce_C_function=np.min, gridsize=20)

# %% [markdown]
# # pie plot
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/25-Pandas_Pie_plot.ipynb

# %%
series = pd.Series(3 * np.random.rand(4),
                   index=['a', 'b', 'c', 'd'], name='series')

# %%
series.plot.pie(figsize=(6,6))

# %%
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], #라벨
                colors=['r', 'g', 'b', 'c'],     #색깔
                autopct='%.2f',                  #%값
                fontsize=20, 
                figsize=(6, 6))

# %% [markdown]
# # Scatter matrix plot 산점도 + 커널 밀도 함수
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/26-Scatter_Matrix_Plot.ipynb

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.846543 -1.310731  0.590452  1.033686
# 1 -0.570954 -1.220148 -0.476919  1.480420
# 2  1.318135 -0.343091  1.348258  0.467353
# 3  1.096055 -0.853785 -0.166680  0.581828
# 4 -1.323169 -1.311865 -0.487240 -0.643591

# %%
scatter_matrix(df, alpha = 0.2, figsize=(6,6), diagonal='kde') #diagonal(대각선)에 kde(커널 밀도 함수를 의미)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8277AF5C8>,
# ...
#       dtype=object)

# %% [markdown]
# # KDE란?
# https://github.com/corazzon/cracking-the-pandas-cheat-sheet/blob/master/27-Kernel_Density_Estimate_plot.ipynb

# %% [markdown]
# 끊겨있는 이산형 변수에서 **확률 밀도 함수를 추정** 하는 비모수적 방법

# %%
ser = pd.Series(np.random.randn(1000))

# %%
ser.plot.density()

# %%
ser.plot.kde()

# %%
ser.plot.hist()
